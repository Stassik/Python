# %% [markdown]
# <a href="https://colab.research.google.com/github/Stassik/Python/blob/main/dataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего
# из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без
# get_dummies?

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  human
# 2  robot
# 3  human
# 4  robot

# %%
data['human'] = 0
data['robot'] = 0

# %%
data.head()
# Out:
#   whoAmI  human  robot
# 0  robot      0      0
# 1  human      0      0
# 2  robot      0      0
# 3  human      0      0
# 4  robot      0      0

# %%
data.loc[data['whoAmI']=='human', 'human'] = '1'
data.loc[data['whoAmI']=='robot', 'robot'] = '1'
data.head()
# Out:
#   whoAmI human robot
# 0  robot     0     1
# 1  human     1     0
# 2  robot     0     1
# 3  human     1     0
# 4  robot     0     1
